# %%
import lyricsgenius as genius
api = genius.Genius('EFnhqpioY4nRkiNkDmk1yWu6-yYi3RtdgsvS7is-76ZEyYca8Qvmv7SeLRpiSdmk')
api.remove_section_headers = True
api.skip_non_songs = True
api.excluded_terms = ["(Live)"]
api.timeout=9999
artist = api.search_artist('Lil Wayne', max_songs=100, get_full_info=False)
print(artist)

artist.save_lyrics()
# Out:
# Searching for songs by Lil Wayne...
#
# Song 1: "Love Me"
# Song 2: "Mona Lisa"
# Song 3: "6 Foot 7 Foot"
# Song 4: "Believe Me"
# Song 5: "Mirror"
# Song 6: "A Milli"
# Song 7: "Rich As Fuck"
# Song 8: "She Will"
# Song 9: "Lollipop (Remix)"
# Song 10: "Don’t Cry"
# Song 11: "Blunt Blowin’"
# Song 12: "Right Above It"
# Song 13: "Uproar"
# Song 14: "Drop the World"
# Song 15: "No Worries"
# Song 16: "How to Love"
# Song 17: "John"
# Song 18: "Lollipop"
# Song 19: "Mr. Carter"
# Song 20: "Dedicate"
# Song 21: "Mrs. Officer"
# Song 22: "Let It Fly"
# Song 23: "God Bless Amerika"
# Song 24: "My Homies Still"
# Song 25: "Can’t Be Broken"
# Song 26: "Glory"
# Song 27: "Let It All Work Out"
# Song 28: "How to Hate"
# Song 29: "Grindin’"
# Song 30: "It’s Good"
# Song 31: "President Carter"
# Song 32: "Pussy Money Weed"
# Song 33: "I’m Good (Dedication 5)"
# Song 34: "I’m Single"
# Song 35: "Family Feud"
# Song 36: "CoCo"
# Song 37: "I Feel Like Dying"
# Song 38: "Wowzers"
# ...
