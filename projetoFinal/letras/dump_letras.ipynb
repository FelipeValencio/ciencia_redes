# %%
import lyricsgenius as genius
api = genius.Genius('EFnhqpioY4nRkiNkDmk1yWu6-yYi3RtdgsvS7is-76ZEyYca8Qvmv7SeLRpiSdmk')
api.remove_section_headers = True
api.skip_non_songs = True
api.excluded_terms = ["(Remix)", "(Live)"]
api.timeout=9999
artist = api.search_artist('Eminem', max_songs=100)
print(artist)

artist.save_lyrics()
# Out:
# Searching for songs by Eminem...
#
# Song 1: "Rap God"
# Song 2: "Lose Yourself"
# Song 3: "Without Me"
# Song 4: "Mockingbird"
# Song 5: "The Real Slim Shady"
# Song 6: "Killshot"
# Song 7: "Godzilla"
# Song 8: "Stan"
# Song 9: "Houdini"
# Song 10: "The Monster"
# Song 11: "Lucky You"
# Song 12: "The Ringer"
# Song 13: "Superman"
# Song 14: "’Till I Collapse"
# Song 15: "Love the Way You Lie"
# Song 16: "Venom"
# Song 17: "River"
# Song 18: "8 Mile: B-Rabbit vs Papa Doc"
# Song 19: "Not Alike"
# Song 20: "Berzerk"
# Song 21: "Fall"
# Song 22: "Cleanin’ Out My Closet"
# Song 23: "Beautiful"
# Song 24: "Kamikaze"
# Song 25: "Bad Guy"
# Song 26: "Walk on Water"
# Song 27: "When I’m Gone"
# Song 28: "The Way I Am"
# Song 29: "My Name Is"
# Song 30: "Not Afraid"
# Song 31: "Sing for the Moment"
# Song 32: "No Love"
# Song 33: "Like Toy Soldiers"
# Song 34: "Headlights"
# Song 35: "Kim"
# Song 36: "Survival"
# Song 37: "Greatest"
# Song 38: "Kill You"
# Song 39: "Love Game"
# Song 40: "Space Bound"
# Song 41: "Marshall Mathers"
# Song 42: "Shake That"
# Song 43: "Criminal"
# Song 44: "Unaccommodating"
# Song 45: "Legacy"
# Song 46: "Gnat"
# Song 47: "White America"
# Song 48: "Guts Over Fear"
# Song 49: "I’m Back"
# Song 50: "FACK"
# Song 51: "Role Model"
# Song 52: "8 Mile"
# Song 53: "Ass Like That"
# Song 54: "Guilty Conscience"
# Song 55: "Darkness"
# Song 56: "Evil Twin"
# Song 57: "Believe"
# Song 58: "Just Don’t Give a Fuck"
# Song 59: "Stronger Than I Was"
# Song 60: "Hailie’s Song"
# Song 61: "Untouchable"
# Song 62: "Business"
# Song 63: "You Gon’ Learn"
# Song 64: "Just Lose It"
# Song 65: "Beautiful Pain"
# Song 66: "So Much Better"
# "Chloraseptic (Remix)" is not valid. Skipping.
# Song 67: "Zeus"
# Song 68: "Infinite"
# Song 69: "The Warning"
# Song 70: "Rhyme or Reason"
# Song 71: "Stepping Stone"
# "The Hills (Eminem Remix)" is not valid. Skipping.
# Song 72: "Campaign Speech"
# Song 73: "Drug Ballad"
# Song 74: "Bitch Please 2"
# Song 75: "Kings Never Die"
# Song 76: "Premonition (Intro)"
# Song 77: "Wicked Ways"
# Song 78: "Good Guy"
# Song 79: "Asshole"
# Song 80: "So Far..."
# Song 81: "Normal"
# Song 82: "Phenomenal"
# Song 83: "Soldier"
# Song 84: "Offended"
# Song 85: "Brainless"
# Song 86: "Square Dance"
# Song 87: "Brain Damage"
# "Runnin’ (Dying to Live)" is not valid. Skipping.
# Song 88: "Under the Influence"
# Song 89: "Leaving Heaven"
# Song 90: "My Dad’s Gone Crazy"
# Song 91: "25 to Life"
# Song 92: "My Darling"
# Song 93: "Antichrist"
# Song 94: "Rock Bottom"
# Song 95: "Those Kinda Nights"
# Song 96: "Cold Wind Blows"
# Song 97: "We Made You"
# Song 98: "I Will"
# Song 99: "Marsh"
# Song 100: "Alfred’s Theme"
#
# Reached user-specified song limit (100).
# Done. Found 100 songs.
# Eminem, 100 songs
# Wrote Lyrics_Eminem.json.
