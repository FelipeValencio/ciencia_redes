# %%
import lyricsgenius as genius
api = genius.Genius('jVnAyistwvRAgqxPEUJAc-xzSpcVluE4r1zpVgyyoGEtfVGgqBYWjAUdSqxVngW5')
api.remove_section_headers = True
api.skip_non_songs = True
api.excluded_terms = ["(Live)"]
api.timeout=9999
artist = api.search_artist('Joey Bada$$', max_songs=100, get_full_info=False)
print(artist)

artist.save_lyrics()
# Out:
# Searching for songs by Joey Bada$$...
#
# Song 1: "Survival Tactics"
# Song 2: "King’s Dead (Freestyle)"
# Song 3: "Paper Trail$"
# Song 4: "Christ Conscious"
# Song 5: "LAND OF THE FREE"
# Song 6: "Hardknock"
# Song 7: "Waves"
# Song 8: "DEVASTATED"
# Song 9: "Love Is Only a Feeling"
# Song 10: "95 Til Infinity"
# Song 11: "Third Eye Shit / Suspect"
# Song 12: "TEMPTATION"
# Song 13: "Killuminati"
# Song 14: "Unorthodox"
# Song 15: "World Domination"
# Song 16: "Hazeus View"
# Song 17: "Snakes"
# Song 18: "Like Me"
# Song 19: "ROCKABYE BABY"
# Song 20: "Big Dusty"
# Song 21: "FromdaTomb$"
# Song 22: "Pennyroyal"
# Song 23: "LEGENDARY"
# Song 24: "Righteous Minds"
# Song 25: "On & On"
# Song 26: "FOR MY PEOPLE"
# Song 27: "My Yout"
# Song 28: "Daily Routine"
# Song 29: "RING THE ALARM"
# "#LongLiveSteelo" is not valid. Skipping.
# Song 30: "Don’t Front"
# Song 31: "BABYLON"
# Song 32: "Killuminati Pt. 2"
# Song 33: "AMERIKKKAN IDOL"
# Song 34: "Enter the Void"
# ...
